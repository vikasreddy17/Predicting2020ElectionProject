# %%
from main import basic_election_prediction
from getData import getPollData
from pprint import pprint
from us_electoral import ec_result, state_raw2win
from state_data_2020 import electoral_college, nomineePartyMap
import random
import pandas as pd

data_source_1 = 'https://www.270towin.com/2020-polls-biden-trump/'
data_source_2 = 'http://www.electproject.org/2020g'
data_source_3 = 'https://www.nbcnews.com/politics/2020-election?icid=election_nav'

def simulation():
    voter_turnout_data = pd.read_csv("2020 November General Election - Turnout Rates.csv")
    raw_state_data = getPollData()
    simulation_results = {}
    state_number = 1
    for state in raw_state_data.keys():
        temporary_state_dictionary = raw_state_data[state]
    
        party_list = []
        party_thresholds = {'DEM': 0, 'REP': 0, 'LIB': 0, 'GRE': 0, 'IND': 0, 'CON': 0, 'OTH': 0, 'PSL': 0, 'SWP': 0}
        party_sim_tally = {'DEM': 0, 'REP': 0, 'LIB': 0, 'GRE': 1, 'IND': 0, 'CON': 0, 'OTH': 0, 'PSL': 0, 'SWP': 0}
        for party in temporary_state_dictionary.keys():
            party_list.append(party)
            for sum_party in party_list:
                old = party_thresholds[party]
                add = temporary_state_dictionary[sum_party]
                party_thresholds[party] = old + add
                sum_percents = party_thresholds[party]
    
        voting_population_of_state = voter_turnout_data.at[state_number,'Estimated_Vote']
        voting_population_of_state = int(voting_population_of_state)
    
        for i in range(voting_population_of_state):
            random_number = random.uniform(0, sum_percents)
            for party_sim in party_thresholds:
                if party_thresholds[party_sim] > random_number:
                    party_sim_tally[party_sim] += 1
        party_list1 = []
        new_party_sim_tally = party_sim_tally
        for party in temporary_state_dictionary.keys():
            for minus_party in party_list1:
                new_party_sim_tally[party] = party_sim_tally[party] - party_sim_tally[minus_party]
            party_list1.append(party)
        simulation_results[state] = new_party_sim_tally
        state_number += 1
        print(state + " simulation is done!")

    print("*"*30)
    print(basic_election_prediction(simulation_results))
    print("*"*30)

    simulation_results = pd.DataFrame(simulation_results)
    simulation_results.to_csv("simulation_results.csv")
    
simulation()
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /opt/tljh/user/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3417: DtypeWarning: Columns (6,22,25,29) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Alabama simulation is done!
# Alaska simulation is done!
# Arizona simulation is done!
# Arkansas simulation is done!
# California simulation is done!
# Colorado simulation is done!
# Connecticut simulation is done!
# Delaware simulation is done!
# District of Columbia simulation is done!
# Florida simulation is done!
# Georgia simulation is done!
# Hawaii simulation is done!
# Idaho simulation is done!
# Illinois simulation is done!
# Indiana simulation is done!
# Iowa simulation is done!
# Kansas simulation is done!
# Kentucky simulation is done!
# Louisiana simulation is done!
# Maine simulation is done!
# Maine CD-1 simulation is done!
# Maine CD-2 simulation is done!
# Maryland simulation is done!
# Massachusetts simulation is done!
# Michigan simulation is done!
# Minnesota simulation is done!
# Mississippi simulation is done!
# Missouri simulation is done!
# Montana simulation is done!
# Nebraska simulation is done!
# Nebraska CD-1 simulation is done!
# Nebraska CD-2 simulation is done!
# Nevada simulation is done!
# New Hampshire simulation is done!
# New Jersey simulation is done!
# New Mexico simulation is done!
# New York simulation is done!
# North Carolina simulation is done!
# North Dakota simulation is done!
# Ohio simulation is done!
# Oklahoma simulation is done!
# Oregon simulation is done!
# Pennsylvania simulation is done!
# Rhode Island simulation is done!
# South Carolina simulation is done!
# South Dakota simulation is done!
# Tennessee simulation is done!
# Texas simulation is done!
# Utah simulation is done!
# Vermont simulation is done!
# Virginia simulation is done!
# Washington simulation is done!
# West Virginia simulation is done!
# Wisconsin simulation is done!
# Wyoming simulation is done!
# ******************************
# Biden, Joe
# ******************************
